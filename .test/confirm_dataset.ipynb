# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
from src.my_app import PreTrainDataset
from src.my_app.core.MyDataset.NewMyDataset import PreTrainDataset_new
import torch
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
# データセットの設定
test_doc_id_list = ['100241706', '100249371', '100249376', '100249416', '100249476', '100249537', '200003076', '200003803', '200003967', '200004107']
transform = transforms.Compose([
    transforms.ToTensor()
])

# データセットの作成
dataset = PreTrainDataset(
    input_path='../../kuzushiji-recognition/synthetic_images/input_images/',
    json_path='../../kuzushiji-recognition/synthetic_images/gt_json.json',
    test_doc_id_list=test_doc_id_list,
    test_mode=False,
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    precompute_gt=False,
    transform=transform,
    target_width=400  # 横幅を400ピクセルに固定
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # データセットの設定
#       2 test_doc_id_list = ['100241706', '100249371', '100249376', '100249416', '100249476', '100249537', '200003076', '200003803', '200003967', '200004107']
# ----> 3 transform = transforms.Compose([
#       4     transforms.ToTensor()
#       5 ])
#       7 # データセットの作成
#       8 dataset = PreTrainDataset(
#       9     input_path='../../kuzushiji-recognition/synthetic_images/input_images/',
#      10     json_path='../../kuzushiji-recognition/synthetic_images/gt_json.json',
#    (...)
#      16     target_width=400  # 横幅を400ピクセルに固定
#      17 )
#
# NameError: name 'transforms' is not defined

# %%
# データセットの設定
test_doc_id_list = ['100241706', '100249371', '100249376', '100249416', '100249476', '100249537', '200003076', '200003803', '200003967', '200004107']
transform = transforms.Compose([
    transforms.ToTensor()
])

# データセットの作成
dataset = PreTrainDataset_new(
    input_path='../../kuzushiji-recognition/synthetic_images/input_images/',
    json_path='../../kuzushiji-recognition/synthetic_images/gt_json.json',
    test_doc_id_list=test_doc_id_list,
    test_mode=False,
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    precompute_gt=False,
    transform=transform,
    target_width=400  # 横幅を400ピクセルに固定
)
# Out:
# Using device: cuda
# jsonデータを読み込みました。

# %%
# インデックス0の画像とその正解データを取得
image, tensor_gt = dataset[0]

# 画像の表示
plt.figure(figsize=(15, 10))

# 元の画像を表示
plt.subplot(2, 3, 1)
plt.title('Input Image')
plt.imshow(image.permute(1, 2, 0))  # CHW -> HWC
plt.axis('off')

# 正解データの各チャネルを表示
channel_names = ['Main Region', 'Main Affinity', 'Furigana Region', 'Furigana Affinity']
for i, name in enumerate(channel_names):
    plt.subplot(2, 3, i + 2)
    plt.title(name)
    plt.imshow(tensor_gt[i].cpu().numpy(), cmap='gray')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # インデックス0の画像とその正解データを取得
# ----> 2 image, tensor_gt = dataset[0]
#       4 # 画像の表示
#       5 plt.figure(figsize=(15, 10))
#
# File c:\Users\kotat\MyPrograms\MyKuzushiji\Craft_respect\src\my_app\core\MyDataset\NewMyDataset.py:84, in PreTrainDataset_new.__getitem__(self, index)
#      81     tensor_gt = self.precomputed_gt[image_id]
#      82 else:
#      83     # リアルタイムで正解データを生成（既に低解像度）
# ---> 84     tensor_gt = self.return_tensor_gt_optimized(
#      85         gt_info_dic=self.gt_json['files'][image_id],
#      86         image=image
#      87     )
#      89 if self.transform:
#      90     image = self.transform(image)
#
# File c:\Users\kotat\MyPrograms\MyKuzushiji\Craft_respect\src\my_app\core\MyDataset\NewMyDataset.py:149, in PreTrainDataset_new.return_tensor_gt_optimized(self, gt_info_dic, image)
#     142         for points in gt_info_dic[channel_name]:
#     143             # points: [p1x, p1y, p2x, p2y, ...]
#     144             scaled_points.append([
#     145                 points[k] * (scale_factor_w if k % 2 == 0 else scale_factor_h)
#     146                 for k in range(len(points))
#     147             ])
# --> 149         canvas_tensor = self.design_gaussian_map_gpu(
#     150             chunk_tensor[j] if chunk_tensor.shape[0] > j else chunk_tensor,
#     151             scaled_points,
#     152             w, h
#     153         )
#     154         chunk_tensor[j] = canvas_tensor
#     156 # 処理が終わったらすぐにCPUに転送
#
# File c:\Users\kotat\MyPrograms\MyKuzushiji\Craft_respect\src\my_app\core\MyDataset\NewMyDataset.py:182, in PreTrainDataset_new.design_gaussian_map_gpu(self, canvas_tensor, point_list, width, height)
#     177     # 四角形の各頂点
#     178     src_points = torch.tensor([
#     179         [p1x, p1y], [p2x, p2y], [p3x, p3y], [p4x, p4y]
#     180     ], dtype=torch.float32, device=self.device)
# --> 182     canvas_tensor = self.add_perspective_gaussian_gpu(
#     183         canvas_tensor, src_points, width, height
#     184     )
#     186 return canvas_tensor
#
# File c:\Users\kotat\MyPrograms\MyKuzushiji\Craft_respect\src\my_app\core\MyDataset\NewMyDataset.py:223, in PreTrainDataset_new.add_perspective_gaussian_gpu(self, canvas, src_points, canvas_width, canvas_height)
#     220 matrix_tensor = torch.from_numpy(matrix).to(self.device)
#     222 # 変換をGPU上で実行
# --> 223 transformed_gaussian = self.warp_perspective_gpu(
#     224     gaussian, matrix_tensor, canvas_width, canvas_height
#     225 )
#     227 # 正規化された値（0-1の範囲）を保持
#     228 canvas = torch.max(canvas, transformed_gaussian)
#
# File c:\Users\kotat\MyPrograms\MyKuzushiji\Craft_respect\src\my_app\core\MyDataset\NewMyDataset.py:258, in PreTrainDataset_new.warp_perspective_gpu(self, image_tensor, matrix, output_width, output_height)
#     256 """GPU上で透視変換を実行"""
#     257 # 変換行列をテンソルに変換
# --> 258 matrix_tensor = torch.from_numpy(matrix).float().to(self.device)
#     260 # グリッドを生成
#     261 grid = self.create_transformation_grid(
#     262     matrix_tensor, output_height, output_width
#     263 )
#
# TypeError: expected np.ndarray (got Tensor)

# %% [markdown]
# 表示される内容の説明：
# 1. Input Image: 入力画像
# 2. Main Region: 本文文字の領域
# 3. Main Affinity: 本文文字間の関連性
# 4. Furigana Region: ふりがなの領域
# 5. Furigana Affinity: ふりがな間の関連性

# %%
# 複数の画像をループで表示
num_samples = 3  # 表示する画像の数

for idx in range(num_samples):
    image, tensor_gt = dataset[idx]
    
    plt.figure(figsize=(15, 10))
    
    # 元の画像を表示
    plt.subplot(2, 3, 1)
    plt.title(f'Input Image {idx}')
    plt.imshow(image.permute(1, 2, 0))
    plt.axis('off')
    
    # 正解データの各チャネルを表示
    for i, name in enumerate(channel_names):
        plt.subplot(2, 3, i + 2)
        plt.title(name)
        plt.imshow(tensor_gt[i].cpu().numpy(), cmap='gray')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()
