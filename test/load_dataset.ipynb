# %%
import sys
import os
import torch
import torchvision.transforms as transforms

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:    
    sys.path.append(project_root)
from src.my_app.core.MyDataset.OldMyDataset_speed import PreTrainDataset_old
import multiprocessing as mp

# %%
# --- Dataset ---
transform = transforms.Compose([
    # transforms.Resizeze((128, 128)),
    transforms.ToTensor()
])
test_doc_id_list = ['100241706', '100249371', '100249376', '100249416', '100249476', '100249537', '200003076', '200003803', '200003967', '200004107']

train_dataset = dataset = PreTrainDataset_old(
    input_path='../../kuzushiji-recognition/synthetic_images/input_images/',
    json_path='../../kuzushiji-recognition/synthetic_images/gt_json.json',
    test_doc_id_list=test_doc_id_list,
    test_mode=False,
    # device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    # precompute_gt=True,
    precompute_gt=False,
    transform=transform,
    # target_width=400  # 横幅を400ピクセルに固定
)

test_dataset = PreTrainDataset_old(
    input_path='../../kuzushiji-recognition/synthetic_images/input_images/',
    json_path='../../kuzushiji-recognition/synthetic_images/gt_json.json',
    test_doc_id_list=test_doc_id_list,
    test_mode=True,
    # device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    # precompute_gt=True,
    precompute_gt=False,
    transform=transform,
    # target_width=400  # 横幅を400ピクセルに固定
)


# # 最適化されたDataLoaderの作成
train_dl = PreTrainDataset_old.create_optimized_dataloader_for_old_dataset(
    train_dataset,
    batch_size=1,
    num_workers=min(mp.cpu_count(), 4)
)
# test_dl = PreTrainDataset_old.create_optimized_dataloader_for_old_dataset(
#     test_dataset,
#     batch_size=1,
#     num_workers=min(mp.cpu_count(), 4)
# )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       2 transform = transforms.Compose([
#       3     # transforms.Resizeze((128, 128)),
#       4     transforms.ToTensor()
#       5 ])
#       6 test_doc_id_list = ['100241706', '100249371', '100249376', '100249416', '100249476', '100249537', '200003076', '200003803', '200003967', '200004107']
# ----> 8 train_dataset = dataset = PreTrainDataset_old(
#       9     input_path='../../kuzushiji-recognition/synthetic_images/input_images/',
#      10     json_path='../../kuzushiji-recognition/synthetic_images/gt_json.json',
#      11     test_doc_id_list=test_doc_id_list,
#      12     test_mode=False,
#      13     # device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
#      14     # precompute_gt=True,
#      15     precompute_gt=False,
#      16     transform=transform,
#      17     # target_width=400  # 横幅を400ピクセルに固定
#      18 )
#      20 test_dataset = PreTrainDataset_old(
#      21     input_path='../../kuzushiji-recognition/synthetic_images/input_images/',
#      22     json_path='../../kuzushiji-recognition/synthetic_images/gt_json.json',
#    (...)
#      29     # target_width=400  # 横幅を400ピクセルに固定
#      30 )
#      33 # # 最適化されたDataLoaderの作成
#
# File ~/00_myprograms/Craft_respect/src/my_app/core/MyDataset/OldMyDataset_speed.py:36, in PreTrainDataset_old.__init__(self, test_doc_id_list, test_mode, input_path, json_path, transform, target_width, precompute_gt, cache_dir)
#      34 # 画像のIDをリストにして保管。
#      35 self.input_imageID_list = []
# ---> 36 for file_name in os.listdir(self.input_path):
#      37     file_path = os.path.join(self.input_path, file_name)
#      38     if os.path.isfile(file_path) and file_name.split('.')[-1] == 'jpg':
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../kuzushiji-recognition/synthetic_images/input_images/'

# %%
from matplotlib import pyplot as plt
for data in train_dataset:
    print(data[0][0].shape, data[1][0].shape)
    plt.title(data[2])
    plt.imshow(data[0].permute(1, 2, 0).cpu().numpy())
    plt.axis('off')
    plt.show()
    for i in range(4):
        combined = (data[0] / 2) + (data[1][i] / 2)
        plt.title(data[2])
        plt.imshow(combined.permute(1, 2, 0).cpu().numpy(), cmap='gray')
        plt.axis('off')
        plt.show()
# Out:
# torch.Size([434, 300]) torch.Size([434, 300])
# torch.Size([435, 300]) torch.Size([435, 300])
# torch.Size([420, 300]) torch.Size([420, 300])
# torch.Size([434, 300]) torch.Size([434, 300])
# torch.Size([416, 300]) torch.Size([416, 300])
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 from matplotlib import pyplot as plt
# ----> 2 for data in train_dataset:
#       3     print(data[0][0].shape, data[1][0].shape)
#       4     plt.title(data[2])
#
# File ~/00_myprograms/Craft_respect/src/my_app/core/MyDataset/OldMyDataset_speed.py:58, in PreTrainDataset_old.__getitem__(self, index)
#      56 def __getitem__(self, index):
#      57     image_id = self.input_imageID_list[index]
# ---> 58     image = Image.open(self.input_path + image_id + '.jpg')
#      60     # 1. 元の画像のサイズを取得
#      61     original_w, original_h = image.size
#
# File /opt/anaconda3/envs/torch_env/lib/python3.10/site-packages/PIL/Image.py:3505, in open(fp, mode, formats)
#    3502     filename = os.fspath(fp)
#    3504 if filename:
# -> 3505     fp = builtins.open(filename, "rb")
#    3506     exclusive_fp = True
#    3507 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../kuzushiji-recognition/synthetic_images/input_images/.jpg'

# %%
os.listdir('../../kuzushiji-recognition/synthetic_images/')
# Out:
# ['gt_json.json',
#  '.DS_Store',
#  'gt_json_backup.json',
#  'pre_training_color_annotations.csv',
#  'pre_training_color_furi_annotations.csv']

# %% [markdown]
# # データセットが間違っているかもしれない、確認

# %%
import json

json_path = '../../kuzushiji-recognition/synthetic_images/gt_json.json'
with open(json_path, 'r', encoding='utf-8') as f:
    data_json = json.load(f)

print(type(data_json))
print(list(data_json['files'].keys())[:5])  # 最初の5キーを表示
# Out:
# <class 'dict'>
# ['100241706_sep_100241706_00002_1', '100241706_sep_100241706_00002_2', '100241706_sep_100241706_00003_1', '100241706_sep_100241706_00003_2', '100241706_sep_100241706_00004_1']

# %%
id = 'umgy00000_sep_umgy003_040'
id in data_json['files']  # Trueなら存在する
# Out:
# True

# %%
list(data_json['files'].keys()).count(id)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = data_json['files'][id]['main_region']

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.figure(figsize=(8, 8))
for quad in a:
    # quad: [x0, y0, x1, y1, x2, y2, x3, y3]
    xs = [quad[0], quad[2], quad[4], quad[6], quad[0]]
    ys = [quad[1], quad[3], quad[5], quad[7], quad[1]]
    plt.plot(xs, ys, marker='o')
plt.gca().set_aspect('equal')
plt.title('Quadrilaterals from a')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
#